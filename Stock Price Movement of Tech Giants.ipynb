# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_s=pd.read_csv(r'C:\Users\CODERS ASYLEM\Desktop\pandas data frame\new_internship_data\project_1\META_things.csv')
data_s
# Out:
#             date        Open        High         Low       Close     Volume
# 0     18-05-2012   41.820565   44.754470   37.792663   38.021408  573576400  \
# 1     21-05-2012   36.330686   36.459977   32.819947   33.844326  168192700
# 2     22-05-2012   32.432076   33.406729   30.771188   30.830860  101786600
# 3     23-05-2012   31.198843   32.322677   31.188898   31.825405   73600000
# 4     24-05-2012   32.770227   33.028807   31.596665   32.849789   50237200
# ...          ...         ...         ...         ...         ...        ...
# 3300  07-07-2025  717.599976  727.000000  713.510010  718.349976    9457100
# 3301  08-07-2025  721.570007  722.909973  714.809998  720.669983    7770700
# 3302  09-07-2025  722.719971  737.530029  722.719971  732.780029   11418000
# 3303  10-07-2025  731.549988  735.799988  719.599976  727.239990    9913600
# 3304  11-07-2025  722.500000  725.159973  709.700012  717.510010   10857000
#
#       Dividends  Stock Splits  Transaction_Value
# ...

# %%
data_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3305 entries, 0 to 3304
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3305 non-null   object
#  1   Open               3305 non-null   float64
#  2   High               3305 non-null   float64
#  3   Low                3305 non-null   float64
#  4   Close              3305 non-null   float64
#  5   Volume             3305 non-null   int64
#  6   Dividends          3305 non-null   float64
#  7   Stock Splits       3305 non-null   int64
#  8   Transaction_Value  3305 non-null   float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 232.5+ KB

# %%
data_s.isnull().sum()
# Out:
# date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# Dividends            0
# Stock Splits         0
# Transaction_Value    0
# dtype: int64

# %% [markdown]
# # finding return throughtout this formula
#
# ## (Sale Price - Purchase Price) / Purchase Price) x 100

# %%
data_s['return'] = (data_s['Close'] - data_s['Open'])/data_s['Close']*100
data_s
# Out:
#             date        Open        High         Low       Close     Volume
# 0     18-05-2012   41.820565   44.754470   37.792663   38.021408  573576400  \
# 1     21-05-2012   36.330686   36.459977   32.819947   33.844326  168192700
# 2     22-05-2012   32.432076   33.406729   30.771188   30.830860  101786600
# 3     23-05-2012   31.198843   32.322677   31.188898   31.825405   73600000
# 4     24-05-2012   32.770227   33.028807   31.596665   32.849789   50237200
# ...          ...         ...         ...         ...         ...        ...
# 3300  07-07-2025  717.599976  727.000000  713.510010  718.349976    9457100
# 3301  08-07-2025  721.570007  722.909973  714.809998  720.669983    7770700
# 3302  09-07-2025  722.719971  737.530029  722.719971  732.780029   11418000
# 3303  10-07-2025  731.549988  735.799988  719.599976  727.239990    9913600
# 3304  11-07-2025  722.500000  725.159973  709.700012  717.510010   10857000
#
# ...

# %%
data_s['return'].plot(kind='line',color='pink')
plt.title('return graph')
# Out:
# Text(0.5, 1.0, 'return graph')

# %%
axs = data_s['Open'].plot(style=['-'],color='green')
plt.title('open price')
plt.legend()
plt.plot()
# Out:
# []

# %%
axs = data_s['Close'].plot(style=['-'],color='orange')
plt.title('open price')
plt.legend()
plt.plot()
# Out:
# []

# %%
new=data_s[['High','Low']]

# %%
new.hist()
# Out:
# array([[<Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>]], dtype=object)

# %%
data_s['return'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
correlation=data_s.drop(['date','Stock Splits'],axis=1)

# %%
correlation=correlation.corr()

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >
